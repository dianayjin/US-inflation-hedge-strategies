# %%
# OPTIONAL: Load the "autoreload" extension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

# %% [markdown]
# ### Objective
# The provided code aims to visualize results of the regression model and robustness checks conducted on all asset classes.
#
# ### Outputs
# The regression Analysis for all assets and the Robust Regression Beta Coefficients and Cross-Validation R^2 Scores on all assets(Gold, TIP, VNQ, ^GSPC).
#
# ### Results
# The results obtained by running the model have highlighted different levels of inflation hedging among the strategies analyzed. VNQ (Real Estate ETF) has a beta coefficient higher than one (1.102), indicating superior hedge performance and making it the best strategy among the ones considered.

# %%
import os
import sys
sys.path.append(os.path.abspath(".."))


from src.visualization import visualize

visualize.main()
